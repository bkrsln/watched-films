# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.models import ColumnDataSource

df = pd.read_csv('films.csv', encoding = "ISO-8859-1")

# %%
df
# Out:
#      Position       Const     Created    Modified  Description  \
# 0           1   tt1255953  2011-10-05  2011-10-05          NaN
# 1           2   tt0111161  2011-10-05  2011-10-05          NaN
# 2           3   tt0068646  2011-10-05  2011-10-05          NaN
# 3           4   tt0071562  2011-10-05  2011-10-05          NaN
# 4           5   tt0108052  2011-10-05  2011-10-05          NaN
# ..        ...         ...         ...         ...          ...
# 274       275  tt11301642  2020-12-29  2020-12-29          NaN
# 275       276   tt0098904  2020-12-29  2020-12-29          NaN
# 276       277   tt6412452  2021-01-10  2021-01-10          NaN
# 277       278   tt0425458  2021-01-11  2021-01-11          NaN
# 278       279   tt1795096  2021-01-11  2021-01-11          NaN
#
#                                 Title                                     URL  \
# 0                           Incendies   https://www.imdb.com/title/tt1255953/
# ...

# %%
df.groupby(['Year'])['Your Rating'].mean()
# Out:
# Year
# 1959    8.000000
# 1972    9.000000
# 1974    7.000000
# 1975    7.000000
# 1976    8.000000
# 1979    7.000000
# 1983    8.000000
# 1984    7.000000
# 1988    9.000000
# 1989    8.000000
# 1990    8.000000
# 1991    8.000000
# 1992    7.333333
# 1993    7.750000
# 1994    8.200000
# 1995    7.400000
# 1996    6.000000
# 1997    7.400000
# 1998    7.333333
# 1999    7.200000
# 2000    8.000000
# 2001    7.300000
# 2002    7.444444
# 2003    7.285714
# 2004    6.882353
# 2005    7.250000
# 2006    6.923077
# 2007    7.214286
# 2008    6.937500
# 2009    6.937500
# 2010    7.125000
# 2011    7.461538
# 2012    7.250000
# 2013    7.166667
# 2014    6.687500
# 2015    7.625000
# 2016    7.500000
# 2017    7.250000
# 2018    7.000000
# 2019    7.666667
# 2020    6.666667
# Name: Your Rating, dtype: float64

# %%
output_file('scatter.html')

source = ColumnDataSource(df)

p = figure()

p.circle(x='Year', y='IMDb Rating', source=source, legend_label='IMDb Rating', size=10, color="green", alpha=0.7)
p.circle(x='Year', y='Your Rating', source=source, legend_label='My Rating', size=8, color="red", alpha=0.4)
p.legend.location = "bottom_left"
p.title.text = "Films (Year / Rating)"

show(p)
